# %%
import pandas as pd

df_train = pd.read_csv('/Users/rohith/Documents/Datasets/Linear_Regression/train.csv')
df_test = pd.read_csv('/Users/rohith/Documents/Datasets/Linear_Regression/test.csv')

# %%
import numpy as np

x_train = df_train['x']
y_train = df_train['y']
x_test = df_test['x']
y_test = df_test['y']

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
print(x_train.shape)
# Out:
# (700,)

# %%
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score

clf = LinearRegression(normalize=True)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.98880231503

# %%
print(y_test[0])
print(y_pred[1])
# Out:
# 79.77515201
# [ 20.90082662]

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,10))
plt.scatter(range(len(y_test)),y_test,color='red',label='GT')
plt.plot(range(len(y_test)),y_pred,color='black',label = 'pred')
plt.legend()
plt.show()

# %%
x_train = x_train.reshape(700,1)

# %%
## Linear Regression 
import numpy as np

theta_0 = np.zeros((700,1))
theta_1 = np.zeros((700,1))


loops = 0
while(loops < 1000):
    y = theta_0 + theta_1 * x_train
    error = y - y_train
    mean_sq_er = np.sum(error**2)
    mean_sq_er = mean_sq_er/700
    if(abs(mean_sq_er) <= 0.01):
        break
    theta_0 = theta_0 - 0.00001 * 2 * np.sum(error)/700 
    theta_1 = theta_1 - 0.00001 * 2 * np.sum(error * x_train)/700
    loops += 1
    if(loops%10 == 0):
        print(mean_sq_er)
# Out:
# 968.48297451
# 249.412714939
# 68.6024019636
# 23.1376243352
# 11.7054996176
# 8.83089001259
# 8.1080687238
# 7.92631489409
# 7.88061254915
# 7.86912036822
# 7.86623033763
# 7.86550331892
# 7.86532018988
# 7.86527382199
# 7.86526184274
# 7.86525851056
# 7.86525735271
# 7.86525674163
# 7.86525626807
# 7.86525582912
# 7.8652553989
# 7.86525497092
# 7.86525454352
# 7.86525411631
# 7.86525368918
# 7.86525326209
# 7.86525283505
# 7.86525240806
# 7.86525198111
# 7.8652515542
# 7.86525112733
# 7.86525070051
# 7.86525027373
# 7.86524984699
# 7.8652494203
# 7.86524899365
# 7.86524856704
# 7.86524814047
# 7.86524771395
# 7.86524728747
# 7.86524686103
# 7.86524643464
# 7.86524600829
# 7.86524558198
# 7.86524515571
# 7.86524472949
# 7.86524430331
# 7.86524387717
# 7.86524345108
# 7.86524302503
# 7.86524259902
# 7.86524217305
# 7.86524174713
# 7.86524132125
# 7.86524089541
# 7.86524046961
# 7.86524004386
# 7.86523961815
# 7.86523919249
# 7.86523876686
# 7.86523834128
# 7.86523791574
# ...

# %%
x_test = x_test.reshape(300,1)
y_test = y_test.reshape(300,1)

# %%
a_0 = theta_0[0]
a_1 = theta_1[0]

# %%
print(a_1)
# Out:
# [ 0.99882364]

# %%
y_prediction = a_0 + a_1 * x_test

# %%
print(r2_score(y_test,y_prediction))
# Out:
# 0.988772002704

# %%
y_plot = []
for i in range(100):
    y_plot.append(a_0 + a_1 * i)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_test,y_test,color='red',label='GT')
plt.plot(range(len(y_plot)),y_plot,color='black',label = 'pred')
plt.legend()
plt.show()
